# %%
import sys
import os
import importlib

project_root = os.path.abspath(os.path.join('..'))  # one level up from notebooks/
sys.path.append(os.path.join(project_root, 'src'))  # add src folder to path

from basicagent import BasicAgent  as agent
#importlib.reload(basicagent)
from second import Employee


print(sys.version)
print("hello i am ipynb file")

agent =BasicAgent()

agent.percept("hello")

agent.percept("hhh")

#basic=AiAgentDemo()

em=Employee()
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:09:02) [GCC 11.2.0]
# hello i am ipynb file
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13 print(sys.version)
#      14 print("hello i am ipynb file")
# ---> 16 agent =BasicAgent()
#      18 agent.percept("hello")
#      20 agent.percept("hhh")
#
# NameError: name 'BasicAgent' is not defined
